# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
master_data = pd.read_csv('../Resources/master_data.csv')

# %%
master_data.head()
# Out:
#    Unnamed: 0                          name  year  selling_price  km_driven  \
# 0           0        Maruti Swift Dzire VDI  2014         450000     145500
# 1           1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2           2      Honda City 2017-2020 EXi  2006         158000     140000
# 3           3     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4           4        Maruti Swift VXI BSIII  2007         130000     120000
#
#      fuel seller_type transmission         owner manufacturer made_in  \
# 0  Diesel  Individual       Manual   First Owner       Maruti   India
# 1  Diesel  Individual       Manual  Second Owner        Skoda  Europe
# 2  Petrol  Individual       Manual   Third Owner        Honda    Asia
# 3  Diesel  Individual       Manual   First Owner      Hyundai    Asia
# 4  Petrol  Individual       Manual   First Owner       Maruti   India
#
#          price_group
# 0  400,000 - 600,000
# 1  200,000 - 400,000
# 2   20,000 - 200,000
# 3  200,000 - 400,000
# 4   20,000 - 200,000

# %%
# selling price vs km driven
dat = master_data[(master_data['selling_price']<35_00_000) & (master_data['km_driven']<10_00_000)]

sns.regplot(data = master_data, x='km_driven', y='selling_price')
plt.ticklabel_format(style='plain', axis='y')

# %%
# selling price vs owner
sns.catplot(data = master_data, x='owner', y='selling_price')
plt.ticklabel_format(style='plain', axis='y')
plt.figure(figsize=(15,10))
plt.show()

# %%
# year vs selling_price
plt.figure(figsize=(15,7))
sns.boxplot(data = master_data, x='year', y='selling_price')
plt.ticklabel_format(style='plain', axis='y')

# %%
# selling price vs owner
sns.catplot(data = master_data, x='fuel', y='selling_price')
plt.ticklabel_format(style='plain', axis='y')
plt.figure(figsize=(15,10))
plt.show()

# %%
# transmission vs selling_price
plt.figure(figsize=(10,10))
plt.ticklabel_format(style='plain', axis='y')
sns.boxplot(data = master_data, x='transmission', y='selling_price')
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
# seller_type vs selling_price
plt.figure(figsize=(7,7))
plt.ticklabel_format(style='plain', axis='y')
sns.boxplot(data = master_data, x='fuel', y='selling_price')
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %%
master_data["selling_price"].describe()
# Out:
# count    1.244600e+04
# mean     5.895504e+05
# std      7.329144e+05
# min      2.000000e+04
# 25%      2.400000e+05
# 50%      4.160000e+05
# 75%      6.500000e+05
# max      1.000000e+07
# Name: selling_price, dtype: float64

# %%
avg_price =     589550
first_q_price = 240000
median_price =  416000
third_q_price = 650000

# %%
most_prices = master_data[(master_data['selling_price'] < 800000)]['selling_price']

# %%
plt.figure(figsize=(20,5))

price_bins = [0, 200000, 400000, 600000, 1000000]

# Visualize distribution of selling price grouped by bucket
plt.hist(master_data["selling_price"], bins=price_bins, rwidth=.9)
plt.title("Number of Cars Sold per Price Range")
plt.xlabel("Selling Price (Rupees)")
plt.ylabel("Number of Cars Sold")
plt.ticklabel_format(style='plain')
