# %%
from sqlalchemy import create_engine
import pandas as pd
from config import db_password

# %%
# Files to load
UserInfo_data_to_load = "Resources/CarDetailsV3_UserInfo.csv"
EngineInfo_data_to_load = "Resources/CarDetailsV3_CarEngineInfo.csv"
CarYear_data_to_load = "Resources/CarDetailsV3_CarYear.csv"

# %%
# Read the data files and store it in a pandas DataFrame.
UserInfo_df = pd.read_csv(UserInfo_data_to_load)
UserInfo_df.head(10)
# Out:
#                                    name seller_type transmission         owner
# 0                Maruti Swift Dzire VDI  Individual       Manual   First Owner
# 1          Skoda Rapid 1.5 TDI Ambition  Individual       Manual  Second Owner
# 2              Honda City 2017-2020 EXi  Individual       Manual   Third Owner
# 3             Hyundai i20 Sportz Diesel  Individual       Manual   First Owner
# 4                Maruti Swift VXI BSIII  Individual       Manual   First Owner
# 5         Hyundai Xcent 1.2 VTVT E Plus  Individual       Manual   First Owner
# 6          Maruti Wagon R LXI DUO BSIII  Individual       Manual   First Owner
# 7                    Maruti 800 DX BSII  Individual       Manual  Second Owner
# 8                      Toyota Etios VXD  Individual       Manual   First Owner
# 9  Ford Figo Diesel Celebration Edition  Individual       Manual   First Owner

# %%
EngineInfo_df = pd.read_csv(EngineInfo_data_to_load)
EngineInfo_df.head(10)
# Out:
#                                    name  selling_price  km_driven    fuel  \
# 0                Maruti Swift Dzire VDI         450000     145500  Diesel
# 1          Skoda Rapid 1.5 TDI Ambition         370000     120000  Diesel
# 2              Honda City 2017-2020 EXi         158000     140000  Petrol
# 3             Hyundai i20 Sportz Diesel         225000     127000  Diesel
# 4                Maruti Swift VXI BSIII         130000     120000  Petrol
# 5         Hyundai Xcent 1.2 VTVT E Plus         440000      45000  Petrol
# 6          Maruti Wagon R LXI DUO BSIII          96000     175000     LPG
# 7                    Maruti 800 DX BSII          45000       5000  Petrol
# 8                      Toyota Etios VXD         350000      90000  Diesel
# 9  Ford Figo Diesel Celebration Edition         200000     169000  Diesel
#
#       mileage   engine   max_power                    torque  seats
# 0   23.4 kmpl  1248 CC      74 bhp            190Nm@ 2000rpm    5.0
# ...

# %%
CarYear_df = pd.read_csv(CarYear_data_to_load)
CarYear_df.head(10)
# Out:
#                                    name  year
# 0                Maruti Swift Dzire VDI  2014
# 1          Skoda Rapid 1.5 TDI Ambition  2014
# 2              Honda City 2017-2020 EXi  2006
# 3             Hyundai i20 Sportz Diesel  2010
# 4                Maruti Swift VXI BSIII  2007
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017
# 6          Maruti Wagon R LXI DUO BSIII  2007
# 7                    Maruti 800 DX BSII  2001
# 8                      Toyota Etios VXD  2011
# 9  Ford Figo Diesel Celebration Edition  2013

# %%
# Create the connection string using the password from the config.py file
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Car_Dekho_Prediction"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Import the CarYear file to PostGreSQL
CarYear_df.to_sql(name='CarYear', con=engine)

# %%
# Import the EngineInfo file to PostGreSQL
EngineInfo_df.to_sql(name='CarEngineInfo', con=engine)

# %%
# Import the UserInfo file to PostGreSQL
UserInfo_df.to_sql(name='UserInfo', con=engine)
